# %%
#%run run.py

# %%
from time import time
import utils
import plot
import test

# %%
from importlib import reload
reload(utils)
reload(plot)
# Out:
# <module 'plot' from '/home/cholobetz/projects/torch_tem/plot.py'>

# %%
DATE = '2022-03-11'

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=1, index='0', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 442.53229236602783 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=2, index='1000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 396.195595741272 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='2000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 340.5013072490692 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='3000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 408.425176858902 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='4000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 473.66832733154297 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='5000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 442.09968972206116 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='6000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 526.0035245418549 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='7000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 405.31166529655457 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='8000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 523.5230214595795 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='9000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 478.08171796798706 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='10000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 472.1106035709381 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='11000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 402.50923442840576 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='12000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 547.1577126979828 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='13000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 429.8199326992035 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='14000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 425.83816599845886 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='15000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 407.11177110671997 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='16000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 421.59557485580444 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='17000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 509.82022356987 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='20000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 495.50036549568176 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='26000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 418.61276149749756 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='28000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 457.3857250213623 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='30000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 517.9011092185974 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='35000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 18.862818717956543 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='40000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 18.001712799072266 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='0', env_to_plot=0, index='45000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# -------------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-94-050d043d1839> in <module>
#       1 time0 = time()
#       2
# ----> 3 test.test_model(date=DATE, run='0', env_to_plot=0, index='45000', which_plots=['zero-shot'], seed=0)
#       4
#       5 print('ran in {0} seconds'.format(time() - time0))
#
# ~/projects/torch_tem/test.py in test_model(date, run, env_to_plot, index, which_plots, seed)
#      36
#      37     # Load the parameters of the model
# ---> 38     params = torch.load('/cumulus/cristofer/TEM_data/' + date + '/run' + run + '/model/params_' + index + '.pt')
#      39     # Create a new tem model with the loaded parameters
#      40     tem = model.Model(params)
#
# ~/anaconda3/envs/tem_pt/lib/python3.9/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     577         pickle_load_args['encoding'] = 'utf-8'
#     578
# ...

# %% [markdown]
# ### run1

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='0', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 350.1460576057434 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='1000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 263.873220205307 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='2000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 287.54342555999756 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='3000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 366.65222454071045 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='4000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 268.3042023181915 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='5000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 238.38331151008606 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='6000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 256.639288187027 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='10000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 216.94600296020508 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='15000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 274.92352747917175 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='20000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 220.64111614227295 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='25000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 323.4436845779419 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='30000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 314.60530614852905 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='35000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 401.66257214546204 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='40000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 330.7655813694 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='45000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 242.53420662879944 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='50000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 198.10874891281128 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='55000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 204.34649634361267 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='60000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 267.0226368904114 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='65000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 305.9781379699707 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='69000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 367.79116892814636 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='70000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 303.9233093261719 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='75000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 269.16513657569885 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='80000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 283.87494373321533 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='85000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 316.17781615257263 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='90000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 308.5669906139374 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='70000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 13.792444705963135 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='75000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 9.975086688995361 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='80000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 8.790338039398193 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='85000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 9.168080568313599 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='90000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 9.801790714263916 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='95000', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 11.643176555633545 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='99999', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 356.2732846736908 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='99999', which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 8.785928726196289 seconds

# %%
for seed in range(1, 15):
    
    time0 = time()

    test.test_model(date=DATE, run='1', env_to_plot=0, index='69000', which_plots=['zero-shot'], seed=seed)

    print('ran seed {0} in {1} seconds'.format(seed, time() - time0))
# Out:
# ran seed 1 in 1110.7821774482727 seconds
# ran seed 2 in 196.00524401664734 seconds
# ran seed 3 in 1706.3591678142548 seconds
# ran seed 4 in 349.093953371048 seconds
# ran seed 5 in 270.06772661209106 seconds
# ran seed 6 in 336.9071321487427 seconds
# ran seed 7 in 411.9767050743103 seconds
# ran seed 8 in 460.0365033149719 seconds
# ran seed 9 in 421.04129433631897 seconds
# ran seed 10 in 1828.6559045314789 seconds
# ran seed 11 in 236.0525233745575 seconds
# ran seed 12 in 470.3785045146942 seconds
# ran seed 13 in 408.1489017009735 seconds
# ran seed 14 in 321.3145432472229 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=0, index='20000')#, which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# len(p): 5
# how many cells: len(cells[0][0]): 100
# how many cells: len(cells[0][0]): 30
# ran in 305.33320450782776 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=1, index='20000')#, which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# len(p): 5
# how many cells: len(cells[0][0]): 100
# how many cells: len(cells[0][0]): 30
# ran in 242.7550184726715 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=1, index='20000')#, which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# len(p): 5
# how many cells: len(cells[0][0]): 100
# how many cells: len(cells[0][0]): 30
# ran in 302.18432879447937 seconds

# %%
time0 = time()

test.test_model(date=DATE, run='1', env_to_plot=2, index='20000')#, which_plots=['zero-shot'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# len(p): 5
# how many cells: len(cells[0][0]): 100
# how many cells: len(cells[0][0]): 30
# ran in 328.0417275428772 seconds

# %%
DATE_0_2 = '2022-03-18'

# %%
time0 = time()

test.test_model(date=DATE_0_2, run='0', env_to_plot=0, index='9999', seed=5)

print('ran seed {0} in {1} seconds'.format(seed, time() - time0))
# Out:
# len(p): 5
# how many cells: len(cells[0][0]): 100
# how many cells: len(cells[0][0]): 30
# ran seed 14 in 331.13301062583923 seconds

# %%
for seed in range(15):

    time0 = time()

    test.test_model(date=DATE_0_2, run='0', env_to_plot=0, index='9999', which_plots=['zero-shot'], seed=seed)

    print('ran seed {0} in {1} seconds'.format(seed, time() - time0))
# Out:
# ran seed 0 in 196.3932921886444 seconds
# ran seed 1 in 1376.1517503261566 seconds
# ran seed 2 in 186.34991717338562 seconds
# ran seed 3 in 1196.345918416977 seconds
# ran seed 4 in 294.66784834861755 seconds
# ran seed 5 in 182.3660023212433 seconds
# ran seed 6 in 180.86730360984802 seconds
# ran seed 7 in 383.19157552719116 seconds
# ran seed 8 in 369.03735852241516 seconds
# ran seed 9 in 319.22029185295105 seconds
# ran seed 10 in 1102.7599515914917 seconds
# ran seed 11 in 185.1320071220398 seconds
# ran seed 12 in 384.06298446655273 seconds
# ran seed 13 in 339.07206988334656 seconds
# ran seed 14 in 166.16312384605408 seconds
