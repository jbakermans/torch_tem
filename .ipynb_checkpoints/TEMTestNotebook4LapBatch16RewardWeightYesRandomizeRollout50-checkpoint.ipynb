# %%
from time import time
import utils
import plot
import test
import analyse
import model
import numpy as np
import torch

# %%
DATE = '2022-04-13'
RUN = '0'
PATH = '/cumulus/cristofer/TEM_data/{0}/run{1}/model/'.format(DATE, RUN)
SAVE_DIR = '/cumulus/cristofer/TEM_figs/{0}/run{1}/'.format(DATE, RUN)

# %%
test.test_recurring(save_dir=SAVE_DIR, model_directory_path=PATH, date=DATE, run=RUN, env_to_plot=0, which_plots=['zero-shot', 'rate_maps'], seed=0, columns=15, already_tested=[], test_period=172800, test_interval=18000)
# Out:
# Found these untested indexes: ['0', '1000', '2000', '3000', '4000']
# Attempting to test all

# %%
from datetime import datetime

# %%
now = datetime.now().strftime("%Y-%m-%d")
now
# Out:
# '2022-04-15'
