# %%
#%run run.py

# %%
from time import time
import utils
import plot
import test

# %%
from importlib import reload
reload(utils)
reload(plot)
# Out:
# <module 'plot' from '/home/cholobetz/projects/torch_tem/plot.py'>

# %%
time0 = time()

test.test_model(date='2022-03-09', run='1', env_to_plot=0, index='19999')

print('ran in {0} seconds'.format(time() - time0))
# Out:
# len(p): 5
# how many cells: len(cells[0][0]): 100
# how many cells: len(cells[0][0]): 30
# ran in 21.35917353630066 seconds

# %%
time0 = time()

test.test_model(date='2022-03-09', run='2', env_to_plot=0, index='49999', which_plots=['zero-shot'])

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 8.296037435531616 seconds

# %%
time0 = time()

test.test_model(date='2022-03-09', run='2', env_to_plot=1, index='49999', which_plots=['zero-shot'])

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 9.261454343795776 seconds

# %%
time0 = time()

test.test_model(date='2022-03-09', run='2', env_to_plot=2, index='49999', which_plots=['zero-shot'])

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 8.98254680633545 seconds

# %%
time0 = time()

test.test_model(date='2022-03-09', run='0', env_to_plot=0, index='20000', which_plots=['zero-shot'])

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 8.98254680633545 seconds

# %%
time0 = time()

test.test_model(date='2022-03-09', run='0', env_to_plot=0, index='49999', which_plots=['zero-shot'])

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 8.98254680633545 seconds

# %%
time0 = time()

test.test_model(date='2022-03-09', run='0', env_to_plot=0, index='99999', which_plots=['zero-shot'])

print('ran in {0} seconds'.format(time() - time0))
# Out:
# ran in 8.98254680633545 seconds

# %%
time0 = time()

test.test_model(date='2022-03-08', run='2', env_to_plot=2, index='19999', which_plots=['zero-shot'])

print('ran in {0} seconds'.format(time() - time0))
