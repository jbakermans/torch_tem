# %%
from time import time
import utils
import plot
import test
import analyse
import model
import numpy as np
import torch

# %%
from importlib import reload
reload(utils)
reload(plot)
reload(model)
# Out:
# <module 'model' from '/home/cholobetz/projects/torch_tem/model.py'>

# %%
DATE = '2022-04-06'

# %%
torch.load('/cumulus/cristofer/TEM_data/2022-04-06/run0/model/params_0.pt')['batch_size']
# Out:
# 16

# %% [markdown]
# ## When testing, do node, edge and tem agents follow same sequence of visits? Is that sequence of visits the same as the training policy?
# ### If not, tem's bad performance could come from the fact that it never travels backwards during training. Thus it never gets a chance to learn backward relationships. If at test time it needs to infer these relationships we could get very bad performance. Should I let it diffuse during training?

# %%
time0 = time()

print('params for {0}'.format(11000))

test.test_model(date=DATE, run='0', env_to_plot=0, index='{0}'.format(11000), which_plots=['zero-shot', 'rate_maps'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# params for 11000
# type(forward): <class 'list'>
# all_g[0][0]: [[nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# ...
