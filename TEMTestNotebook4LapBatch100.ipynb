# %%
from time import time
import utils
import plot
import test
import analyse
import model
import numpy as np
import torch

# %%
DATE = '2022-04-05'

# %%
torch.load('/cumulus/cristofer/TEM_data/2022-04-05/run0/model/params_2000.pt')['batch_size']
# Out:
# 100

# %%
time0 = time()

print('params for {0}'.format(2000))

test.test_model(date=DATE, run='0', env_to_plot=0, index='{0}'.format(2000), which_plots=['zero-shot', 'rate_maps'], seed=0)

print('ran in {0} seconds'.format(time() - time0))
# Out:
# params for 2000
# ran forward method
# type(forward): <class 'list'>
# all_g[0][0]: [[-0.95830643 -0.48045504  0.8848497  -0.9993915  -0.7565841   0.20338303
#    0.97116387  0.19162628  0.8379689  -0.5377983   0.9782328  -0.79187393
#   -0.945819    0.86476797 -0.99469376 -0.7228928  -0.9389362   0.9911403 ]
#  [-0.9597743  -0.48298872  0.8757556  -0.9995662  -0.7603283   0.17632371
#    0.9728957   0.19968992  0.8120757  -0.5253116   0.9821247  -0.7841623
#   -0.9441419   0.86369437 -0.99540627 -0.72198606 -0.93643934  0.99228156]
#  [-0.9589674  -0.4945086   0.87971956 -0.9994706  -0.76393217  0.18320784
#    0.9726666   0.1810764   0.8177915  -0.53118193  0.9802811  -0.7887266
#   -0.9450844   0.8691472  -0.9949802  -0.7308868  -0.9373487   0.991575  ]
#  [-0.95291793 -0.55907226  0.8549404  -0.998837   -0.7664073   0.15418702
#    0.97443527  0.0307531   0.8073822  -0.5139079   0.98229223 -0.79955256
#   -0.95240754  0.8694529  -0.9951075  -0.7847667  -0.9357158   0.99311095]
# ...
